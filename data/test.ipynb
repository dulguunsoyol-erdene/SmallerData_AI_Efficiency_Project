# %%
import pandas as pd
import os

# Data reading
csv_link = 'CSCI_lang_data.csv'

df = pd.read_csv(csv_link)

# Ensure correct column names (optional but recommended)
df.columns = ["word", "label"]

# If you want it as a list of tuples like your original data:
data = list(df.itertuples(index=False, name=None))

# Recreate DataFrame exactly like your format
df = pd.DataFrame(data, columns=["word", "label"])
# Out:
#       word     label
# 0   уншсан      PAST
# 1   харсан      PAST
# 2    ирсэн      PAST
# 3    явдаг  HABITUAL
# 4   хардаг  HABITUAL
# 5   сандаг  HABITUAL
# 6     явна    FUTURE
# 7     иднэ    FUTURE
# 8    харна    FUTURE
# 9      нар     OTHER
# 10     хүн     OTHER
# 11      би     OTHER
# 12     тэр     OTHER
